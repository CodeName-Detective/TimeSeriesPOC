# %%
from random import gauss
import matplotlib.pyplot as plt
import numpy as np
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# # GARCH(2,2) Model
#
# $$
# a_t = \varepsilon_t \sqrt{\omega + \alpha_1 a_{t-1}^2 + \alpha_2 a_{t-2}^2 + \beta_1 \sigma_{t-1}^2 + \beta_2 \sigma_{t-2}^2}
# $$
#
# $$
# a_0, a_1 \sim \mathcal{N}(0,1)
# $$
#
# $$
# \sigma_0 =1, \sigma_1 = 1
# $$
#
# $$
# \varepsilon_t \sim \mathcal{N}(0,1)
# $$

# %%
# create dataset
n = 1000
omega = 0.5

alpha_1 = 0.1
alpha_2 = 0.2

beta_1 = 0.3
beta_2 = 0.4

test_size = int(n*0.1)

series = [gauss(0,1), gauss(0,1)]
vols = [1, 1]

for _ in range(n):
    new_vol = np.sqrt(omega + alpha_1*series[-1]**2 + alpha_2*series[-2]**2 + beta_1*vols[-1]**2 + beta_2*vols[-2]**2)
    new_val = gauss(0,1) * new_vol
    
    vols.append(new_vol)
    series.append(new_val)

# %%
plt.figure(figsize=(10,4))
plt.plot(series)
plt.title('Simulated GARCH(2,2) Data', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Simulated GARCH(2,2) Data')

# %%
plt.figure(figsize=(10,4))
plt.plot(vols)
plt.title('Data Volatility', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Data Volatility')

# %%
plt.figure(figsize=(10,4))
plt.plot(series)
plt.plot(vols, color='red')
plt.title('Data and Volatility', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Data and Volatility')

# %% [markdown]
# # PACF Plot

# %%
plot_pacf(np.array(series)**2)
plt.show()

# %% [markdown]
# # Fit the GARCH Model

# %%
train, test = series[:-test_size], series[-test_size:]

# %%
model = arch_model(train, p=2, q=2)

# %%
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 2658.132088006073
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 2656.4047499505054
# Iteration:      3,   Func. Count:     28,   Neg. LLF: 2654.439419648009
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2652.8223845989123
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2652.0478607058385
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 2651.4687914561828
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2651.057431510645
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 2650.051306505835
# Iteration:      9,   Func. Count:     82,   Neg. LLF: 2650.020306791327
# Iteration:     10,   Func. Count:     91,   Neg. LLF: 2650.0024498119283
# Iteration:     11,   Func. Count:     99,   Neg. LLF: 2650.001062662209
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 2650.0006108552725
# Iteration:     13,   Func. Count:    116,   Neg. LLF: 2650.0005419808285
# Iteration:     14,   Func. Count:    124,   Neg. LLF: 2650.0005393620304
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2650.0005395393628
#             Iterations: 14
#             Function evaluations: 124
#             Gradient evaluations: 14

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2650.00
# Distribution:                  Normal   AIC:                           5312.00
# Method:            Maximum Likelihood   BIC:                           5340.83
#                                         No. Observations:                  902
# Date:                Tue, Jan 12 2021   Df Residuals:                      896
# Time:                        18:56:00   Df Model:                            6
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu            -0.1425      0.113     -1.259      0.208 [ -0.364,7.925e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.5126      0.217      2.363  1.811e-02 [8.749e-02,  0.938]
# alpha[1]       0.1049  3.771e-02      2.783  5.389e-03 [3.103e-02,  0.179]
# alpha[2]       0.1991  4.705e-02      4.232  2.318e-05   [  0.107,  0.291]
# beta[1]        0.3304      0.147      2.244  2.483e-02 [4.183e-02,  0.619]
# beta[2]        0.3656      0.122      3.006  2.646e-03   [  0.127,  0.604]
# ==========================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# # Predict

# %%
predictions = model_fit.forecast(horizon=test_size)

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(vols[-test_size:])
preds, = plt.plot(np.sqrt(predictions.variance.values[-1, :]))
plt.title('Volatility Prediction', fontsize=20)
plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=16)

# %%
predictions_long_term = model_fit.forecast(horizon=1000)
plt.figure(figsize=(10,4))
true, = plt.plot(vols[-test_size:])
preds, = plt.plot(np.sqrt(predictions_long_term.variance.values[-1, :]))
plt.title('Long Term Volatility Prediction', fontsize=20)
plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=16)

# %% [markdown]
# # Rolling Forecast Origin

# %%
rolling_predictions = []
for i in range(test_size):
    train = series[:-(test_size-i)]
    model = arch_model(train, p=2, q=2)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(vols[-test_size:])
preds, = plt.plot(rolling_predictions)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=16)
